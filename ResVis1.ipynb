# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np

# %%
ResultsDF=pd.read_csv('all_policies_results_sorted.csv')
#ResultsDF['Policies'] = ResultsDF['Policies'].str.replace('(',"{")
#ResultsDF['Policies'] = ResultsDF['Policies'].str.replace(')','}')
#ResultsDF['Policies'] = ResultsDF['Policies'].str.replace(":',","': ")

# %%
import matplotlib.cm as mpl_cm
import matplotlib.pylab as pl
SMALL_SIZE = 15
MEDIUM_SIZE = 17
BIGGER_SIZE = 18
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Regulated EV manufacture", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
new_labels=['No','Yes']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.41, 1.05),ncol=2)
for t, l in zip(ridge_plot._legend.texts, new_labels):
    t.set_text(l)
    
ridge_plot.map(plt.axvline, x=21.7, ls='--', c='red')
ridge_plot.savefig("Emissions_ModalShiftWithRegulatedEV.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Regulated EV manufacture", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Used (EJ)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
new_labels=['No','Yes']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.41, 1.05),ncol=2)
for t, l in zip(ridge_plot._legend.texts, new_labels):
    t.set_text(l)

ridge_plot.savefig("Energy_ModalShiftWithRegulatedEV.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Phase-Out", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
new_labels=['2025','2030','2040']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.4, 1.05),ncol=3)
for t, l in zip(ridge_plot._legend.texts, new_labels):
    t.set_text(l)

ridge_plot.savefig("Emissions_ModalShiftWithPhaseOut.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Phase-Out", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Used (EJ)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
new_labels=['2025','2030','2040']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.4, 1.05),ncol=3)
for t, l in zip(ridge_plot._legend.texts, new_labels):
    t.set_text(l)

ridge_plot.savefig("Energy_ModalShiftWithPhaseOut.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Net-Zero", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['2020','2050','2060']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.390, 1.05),ncol=3)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Emissions_ModalShiftWithNetZero.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Net-Zero", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Use (EJ))", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['2020','2050','2060']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.390, 1.05),ncol=3)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Energy_ModalShiftWithNetZero.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Retrofitting", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.39, 1.05),ncol=3)
for t, l in zip(ridge_plot._legend.texts, new_labels):
    t.set_text(l)

ridge_plot.savefig("Emissions_ModalShiftWithRetrofitting.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Retrofitting", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Use (EJ)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.39, 1.05),ncol=3)
for t, l in zip(ridge_plot._legend.texts, new_labels):
    t.set_text(l)

ridge_plot.savefig("Energy_ModalShiftWithRetrofitting.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Scrap Age", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Emissions_ModalShiftWithScrapAge.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Modal Shift", hue="Scrap Age", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Use (EJ)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Energy_ModalShiftWithScrapAge.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Retrofitting", hue="Lightweighting", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Emissions_LightweightingWithRetrofit.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Retrofitting", hue="Lightweighting", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Modal Shift=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Usage (EJ)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Energy_LightweightingWithRetrofit.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Scrap Age", hue="Phase-Out", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Scrap Age=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Emissions_ScrapAgewithPhaseOut.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Scrap Age", hue="Phase-Out", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Scrap Age=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Use (EJ)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Energy_ScrapAgewithPhaseOut.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Scrap Age", hue="Lightweighting", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Scrap Age=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Emissions_ScrapAgewithLightweighting.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Scrap Age", hue="Lightweighting", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Energy", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Scrap Age=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative Energy Use (EJ)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Energy_ScrapAgewithLightweighting.png")

# %%
ResultsDF
# Out:
#       Phase-Out  Net-Zero  Retrofitting  Lightweighting  Modal Shift  \
# 0          2025      2020           0.0            1400           20
# 1          2025      2020           0.0            1400           20
# 2          2025      2020           0.0            1400           20
# 3          2025      2020           0.0            1400           20
# 4          2025      2020           0.0            1400           20
# ...         ...       ...           ...             ...          ...
# 5827       2040      2060           0.5             840          -80
# 5828       2040      2060           0.5             840          -80
# 5829       2040      2060           0.5             840          -80
# 5830       2040      2060           0.5             840          -80
# 5831       2040      2060           0.5             840          -80
#
#       Scrap Age  Regulated EV manufacture   Emissions        Energy
# 0            20                         0  145.041150  2.203207e+12
# 1            20                         1  117.069805  2.191639e+12
# 2            18                         0  141.397752  2.185169e+12
# 3            18                         1  112.248029  2.173074e+12
# 4            16                         0  139.343444  2.184018e+12
# ...         ...                       ...         ...           ...
# 5827         14                         1   40.413571  6.441332e+11
# 5828         12                         0   43.178627  6.519136e+11
# 5829         12                         1   39.780207  6.503415e+11
# 5830         10                         0   43.802626  6.649214e+11
# 5831         10                         1   39.691585  6.627805e+11
#
# [5832 rows x 9 columns]

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Scrap Age", hue="Modal Shift", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Scrap Age=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.33, 1.05),ncol=6)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)

ridge_plot.savefig("Emissions_ScrapAgeWithModalShift.png")

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF, row="Lightweighting", hue="Modal Shift", aspect=5, height=1.75,margin_titles=True)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')
def label(x, color, label):
    ax = plt.gca()
    label='Retrofitting=' +label
    ax.text(0,-0.05, label,rotation='vertical')
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(hspace=-0.001)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.39, 1.05),ncol=3)
for t, l in zip(ridge_plot._legend.texts, new_labels):
    t.set_text(l)

ridge_plot.savefig("Emissions_LightweightingWithModalShift.png")

# %%
ResultsDF
# Out:
#       Phase-Out  Net-Zero  Retrofitting  Lightweighting  Modal Shift  \
# 0          2025      2020           0.0            1400           20
# 1          2025      2020           0.0            1400           20
# 2          2025      2020           0.0            1400           20
# 3          2025      2020           0.0            1400           20
# 4          2025      2020           0.0            1400           20
# ...         ...       ...           ...             ...          ...
# 5827       2040      2060           0.5             840          -80
# 5828       2040      2060           0.5             840          -80
# 5829       2040      2060           0.5             840          -80
# 5830       2040      2060           0.5             840          -80
# 5831       2040      2060           0.5             840          -80
#
#       Scrap Age  Regulated EV manufacture   Emissions        Energy
# 0            20                         0  145.041150  2.203207e+12
# 1            20                         1  117.069805  2.191639e+12
# 2            18                         0  141.397752  2.185169e+12
# 3            18                         1  112.248029  2.173074e+12
# 4            16                         0  139.343444  2.184018e+12
# ...         ...                       ...         ...           ...
# 5827         14                         1   40.413571  6.441332e+11
# 5828         12                         0   43.178627  6.519136e+11
# 5829         12                         1   39.780207  6.503415e+11
# 5830         10                         0   43.802626  6.649214e+11
# 5831         10                         1   39.691585  6.627805e+11
#
# [5832 rows x 9 columns]

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077',)
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')

mask= ResultsDF['Lightweighting'] == 1120
mask1= ResultsDF['Modal Shift'] == -60 
mask2= ResultsDF['Modal Shift'] == -20
mask3= ResultsDF['Modal Shift'] == 20
#df.drop(['C', 'D'], axis = 1)
sns.set_style("whitegrid", {'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF[~mask][~mask1][~mask2][~mask3], col="Lightweighting", hue="Modal Shift",col_order=[1400,840], aspect=0.7, height=8,margin_titles=True,sharex=False,sharey=False)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", vertical=True, clip_on=False, shade=True, alpha=0.3, lw=2,ax=ax)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
#ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')

#ridge_plot.fig.subplots_adjust(wspace=6, hspace=6)

    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(wspace=-0.001)
#ridge_plot.fig.axes[1].invert_yaxis()
ridge_plot.fig.axes[0].set_xlim(0,0.2)
ridge_plot.fig.axes[1].set_xlim(0,0.2)
ridge_plot.fig.axes[0].invert_xaxis()
ridge_plot.fig.axes[0].set_ylim(0,220)
ridge_plot.fig.axes[1].set_ylim(0,220)
#ridge_plot.fig.axes[0].set_ylim(0,)
#ridge_plot.fig.axes[1].set_ylim(0,0.2)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Scenerio Culmulative CO2e Emissions (MtCO2e)", y_var="Probability")
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=True)
#new_labels=['0%','20%','50%']
ridge_plot.add_legend(loc='upper center',bbox_to_anchor=(0.39, 1.05),ncol=3)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)


ridge_plot.savefig("Emissions_LightweightingWithModalShift.png")
# Out:
# <ipython-input-151-127dbc14260a>:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ridge_plot = sns.FacetGrid(ResultsDF[~mask][~mask1][~mask2][~mask3], col="Lightweighting", hue="Modal Shift",col_order=[1400,840], aspect=0.7, height=8,margin_titles=True,sharex=False,sharey=False)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077',)
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')


mask= ResultsDF['Lightweighting'] == 1120

#df.drop(['C', 'D'], axis = 1)
sns.set_style("whitegrid", {'axes.linewidth': 2,'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", rc={"font.size":15,"axes.titlesize":15,"axes.labelsize":15,"legend.title_fontsize":15})   

#sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF[~mask], col="Lightweighting", hue="Modal Shift",col_order=[1400,840], aspect=0.7, height=8,margin_titles=True,sharex=False,sharey=False)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", vertical=True, clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
#ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')

#ridge_plot.fig.subplots_adjust(wspace=6, hspace=6)
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(wspace=-0.001)
ridge_plot.fig.axes[0].set_xlim(0.000001,0.2)
#ridge_plot.fig.axes[0].set_yticks([])
ridge_plot.fig.axes[1].set_xlim(0,0.2)
ridge_plot.fig.axes[0].invert_xaxis()
ridge_plot.fig.axes[0].set_ylim(0,220)
ridge_plot.fig.axes[1].set_ylim(0,220)
ridge_plot.fig.axes[0].set_yticklabels([], size = 15)
ridge_plot.fig.axes[1].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

from matplotlib.ticker import FormatStrFormatter
ridge_plot.fig.axes[0].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ridge_plot.fig.axes[1].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))


#ridge_plot.fig.axes[0].set_ylim(0,)
#ridge_plot.fig.axes[1].set_ylim(0,0.2)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Probability",y_var="Cumulative Emissions up to 2050 (MtCO$_{2eq}$)",fontsize = 17)
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=False, top=False, right=False)
#new_labels=['0%','20%','50%']
#legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.25, 1.15),ncol=3,fontsize=15,frameon=True)
legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.45, 0.92),ncol=3,fontsize=15,frameon=True)

#legend.get_title().set_fontsize(16)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)
sns.set(font_scale = 0.1)


ridge_plot.savefig("Emissions_LightweightingWithModalShift.png")
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <ipython-input-86-bb88df67b464>:34: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[1].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
# <ipython-input-86-bb88df67b464>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
# <ipython-input-86-bb88df67b464>:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077',)
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')


mask= ResultsDF['Lightweighting'] == 1120

#df.drop(['C', 'D'], axis = 1)
sns.set_style("whitegrid", {'axes.linewidth': 2,'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", rc={"font.size":15,"axes.titlesize":15,"axes.labelsize":15,"legend.title_fontsize":15})   

#sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF[~mask], col="Lightweighting", hue="Modal Shift",col_order=[1400,840], aspect=0.7, height=8,margin_titles=True,sharex=False,sharey=False)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", vertical=True, clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
#ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')

#ridge_plot.fig.subplots_adjust(wspace=6, hspace=6)
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(wspace=-0.001)
ridge_plot.fig.axes[0].set_xlim(0.000001,0.2)
#ridge_plot.fig.axes[0].set_yticks([])
ridge_plot.fig.axes[1].set_xlim(0,0.2)
ridge_plot.fig.axes[0].invert_xaxis()
ridge_plot.fig.axes[0].set_ylim(0,220)
ridge_plot.fig.axes[1].set_ylim(0,220)
ridge_plot.fig.axes[0].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
ridge_plot.fig.axes[1].set_yticklabels([], size = 15)
ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

from matplotlib.ticker import FormatStrFormatter
ridge_plot.fig.axes[0].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ridge_plot.fig.axes[1].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))


#ridge_plot.fig.axes[0].set_ylim(0,)
#ridge_plot.fig.axes[1].set_ylim(0,0.2)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Probability",y_var="Cumulative Emissions up to 2050 (MtCO$_{2eq}$)",fontsize = 17)
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=False, top=False, right=False)
#new_labels=['0%','20%','50%']
#legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.25, 1.15),ncol=3,fontsize=15,frameon=True)
legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.45, 0.92),ncol=3,fontsize=15,frameon=True)

#legend.get_title().set_fontsize(16)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)
sns.set(font_scale = 0.1)

plt.savefig('Fig5.png', bbox_inches="tight")
plt.savefig('Fig5.pdf', bbox_inches="tight")


ridge_plot.savefig("Emissions_LightweightingWithModalShift.png")
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <ipython-input-6-164ece014845>:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[0].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
# <ipython-input-6-164ece014845>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
# <ipython-input-6-164ece014845>:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077',)
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')



mask= ResultsDF['Lightweighting'] == 1120
#mask1= ResultsDF['Modal Shift'] == -60 
mask2= ResultsDF['Modal Shift'] == -20
mask3= ResultsDF['Modal Shift'] == 20

#df.drop(['C', 'D'], axis = 1)
sns.set_style("whitegrid", {'axes.linewidth': 2,'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", rc={"font.size":15,"axes.titlesize":15,"axes.labelsize":15,"legend.title_fontsize":15})   

#sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF[~mask][~mask2][~mask3], col="Lightweighting", hue="Modal Shift",col_order=[1400,840], aspect=0.7, height=8,margin_titles=True,sharex=False,sharey=False)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", vertical=True, clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
#ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')

#ridge_plot.fig.subplots_adjust(wspace=6, hspace=6)
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(wspace=-0.001)
ridge_plot.fig.axes[0].set_xlim(0.000001,0.2)
#ridge_plot.fig.axes[0].set_yticks([])
ridge_plot.fig.axes[1].set_xlim(0,0.2)
ridge_plot.fig.axes[0].invert_xaxis()
ridge_plot.fig.axes[0].set_ylim(0,220)
ridge_plot.fig.axes[1].set_ylim(0,220)
ridge_plot.fig.axes[0].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
ridge_plot.fig.axes[1].set_yticklabels([], size = 15)
ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

from matplotlib.ticker import FormatStrFormatter
ridge_plot.fig.axes[0].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ridge_plot.fig.axes[1].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))


#ridge_plot.fig.axes[0].set_ylim(0,)
#ridge_plot.fig.axes[1].set_ylim(0,0.2)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Probability",y_var="Cumulative Emissions up to 2050 (MtCO$_{2eq}$)",fontsize = 17)
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=False, top=False, right=False)
#new_labels=['0%','20%','50%']
#legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.25, 1.15),ncol=3,fontsize=15,frameon=True)
legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.55, 0.92),ncol=2,fontsize=15,frameon=True)

#legend.get_title().set_fontsize(16)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)
sns.set(font_scale = 0.1)

plt.savefig('Fig5_reduced.png', bbox_inches="tight")
plt.savefig('Fig5_reduced.pdf', bbox_inches="tight")


ridge_plot.savefig("Emissions_LightweightingWithModalShift_Reduced.png")
# Out:
# <ipython-input-12-761bde734ba9>:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ridge_plot = sns.FacetGrid(ResultsDF[~mask][~mask2][~mask3], col="Lightweighting", hue="Modal Shift",col_order=[1400,840], aspect=0.7, height=8,margin_titles=True,sharex=False,sharey=False)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <ipython-input-12-761bde734ba9>:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[0].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
# <ipython-input-12-761bde734ba9>:39: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
# <ipython-input-12-761bde734ba9>:40: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


x = np.random.poisson(lam =3, size=100)
y = np.random.choice(["S{}".format(i+1) for i in range(4)], size=len(x))
df = pd.DataFrame({"Scenario":y, "LMP":x})

fig, ax = plt.subplots()

for i, key in enumerate(['S1', 'S2', 'S3', 'S4']):
    ax.violinplot(df[df.Scenario == key]["LMP"].values, positions=[0])

# %%
mask= ResultsDF['Lightweighting'] == 1120
mask2= ResultsDF['Lightweighting'] == 1400

g = sns.catplot(x="Lightweighting", y="Emissions",
                hue="Lightweighting",
                data=ResultsDF[~mask], kind="violin", split=True,
                height=4, aspect=.7,
                gridspec_kws={"hspace":0});

g = sns.catplot(x="Lightweighting", y="Emissions",
                hue="Lightweighting",
                data=ResultsDF[~mask], kind="violin", split=True,
                height=4, aspect=.7,
                gridspec_kws={"hspace":0});



g.fig.subplots_adjust(wspace=6, hspace=0)

#g.fig.tight_layout(pad=0.4, w_pad=4, h_pad=1.0)

# %%
fig, ax = plt.subplots(figsize=(11,8))
mask= ResultsDF['Regulated EV manufacture'] == 0
im=ax.scatter(ResultsDF[mask].Energy/1e12,ResultsDF[mask].Emissions, marker='x', c=ResultsDF[mask]['Modal Shift'],cmap='viridis' ,s=20)
ax.scatter(ResultsDF[~mask].Energy/1e12,ResultsDF[~mask].Emissions, marker='|', c=ResultsDF[mask]['Modal Shift'],cmap='viridis',s=20 )
plt.legend(['No EV Manufacture Regulations','EV Manufacture Regulations','test3'])
fig.colorbar(im, ax=ax,label='Modal Shift Percentage')
plt.savefig('EnergyEmissionsPlot.png')
plt.xlabel('Cumulative Energy to 2050 (EJ)')
plt.ylabel('Cumulative Emissions to 2050 (MtCO2e)')
plt.axhline(y=21.7, ls='--', c='red')
plt.show()
#plt.scatter(ResultsDF.Energy,ResultsDF.Emissions,c=ResultsDF['Modal Shift'],s=2)

# %%
import matplotlib.cm as mpl_cm
import matplotlib.pylab as pl
SMALL_SIZE = 15
MEDIUM_SIZE = 17
BIGGER_SIZE = 18
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)

fig, ax = plt.subplots(figsize=(11,8))
plt.grid()
mask= ResultsDF['Regulated EV manufacture'] == 0
cmap=plt.cm.get_cmap('viridis', 6)
im=ax.scatter(ResultsDF[mask].Energy/1e12,ResultsDF[mask].Emissions, marker='_', c=ResultsDF[mask]['Modal Shift'],cmap=cmap ,s=30, vmax=30,vmin=-90)
ax.scatter(ResultsDF[~mask].Energy/1e12,ResultsDF[~mask].Emissions, marker='|', c=ResultsDF[mask]['Modal Shift'],cmap=cmap,s=30, vmax=30,vmin=-90 )
plt.legend(['No Regulated EV Manufacture','Regulated EV Manufacture','test3'])
fig.colorbar(im, ax=ax,label='Car Travel Activity (%)')
plt.savefig('EnergyEmissionsPlot.png')
plt.xlabel('Cumulative Energy Demand up to 2050 (EJ)')
plt.ylabel('Cumulative Emissions up to 2050 (MtCO$_{2eq}$)')
plt.xlim(0.5,3)
plt.grid()
#plt.axhline(y=21.7, ls='--', c='red')
plt.savefig('Fig4.png', bbox_inches="tight")
plt.savefig('Fig4.pdf', bbox_inches="tight")
plt.show()
#plt.scatter(ResultsDF.Energy,ResultsDF.Emissions,c=ResultsDF['Modal Shift'],s=2)

# %%
#fig, ax = plt.subplots()
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#000077',)
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==20) ].Emissions, fill=True,color='#0000FF')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==1) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#770000')
#sns.kdeplot(ResultsDF[(ResultsDF['Regulated EV manufacture']==0) & (ResultsDF['Modal Shift']==-80)].Emissions, fill=True,color='#FF0000')


mask= ResultsDF['Lightweighting'] == 1120

#df.drop(['C', 'D'], axis = 1)
sns.set_style("whitegrid", {'axes.linewidth': 2,'axes.grid' : True,'axes.edgecolor':'gray'})
sns.set_context("paper", rc={"font.size":15,"axes.titlesize":15,"axes.labelsize":15,"legend.title_fontsize":15})   

#sns.set_context("paper", font_scale=1.29)
# Use FacetGrid to create the facet with one column
ridge_plot = sns.FacetGrid(ResultsDF[~mask], col="Lightweighting", hue="Modal Shift",col_order=[1400,840], aspect=0.7, height=8,margin_titles=True,sharex=False,sharey=False)
# Draw the densities in a few steps
ridge_plot.map(sns.kdeplot, "Emissions", vertical=True, clip_on=False, shade=True, alpha=0.3, lw=2)
#g.map(sns.kdeplot, "co2_emission", clip_on=False, color="b", lw=4, bw=.2)
#ridge_plot.map(plt.axhline, y=0, lw=3, clip_on=True,color='black')

#ridge_plot.fig.subplots_adjust(wspace=6, hspace=6)
    
#ridge_plot.map(label, "Modal Shift")
# Set the subplots to overlap
ridge_plot.fig.subplots_adjust(wspace=-0.001)
ridge_plot.fig.axes[0].set_xlim(0.000001,0.2)
#ridge_plot.fig.axes[0].set_yticks([])
ridge_plot.fig.axes[1].set_xlim(0,0.2)
ridge_plot.fig.axes[0].invert_xaxis()
ridge_plot.fig.axes[0].set_ylim(0,220)
ridge_plot.fig.axes[1].set_ylim(0,220)
ridge_plot.fig.axes[0].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
ridge_plot.fig.axes[1].set_yticklabels([], size = 15)
ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

from matplotlib.ticker import FormatStrFormatter
ridge_plot.fig.axes[0].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
ridge_plot.fig.axes[1].xaxis.set_major_formatter(FormatStrFormatter('%.2f'))


#ridge_plot.fig.axes[0].set_ylim(0,)
#ridge_plot.fig.axes[1].set_ylim(0,0.2)
# Remove axes details that don't play well with overlap
#ridge_plot.set_titles("")
ridge_plot.set_axis_labels(x_var="Probability",y_var="Cumulative Emissions up to 2050 (MtCO$_{2eq}$)",fontsize = 17)
#ridge_plot.set(ytitle="Probablility")
#ridge_plot.set(yticks=[])
ridge_plot.despine(left=False, top=False, right=False)
#new_labels=['0%','20%','50%']
#legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.25, 1.15),ncol=3,fontsize=15,frameon=True)
legend=ridge_plot.add_legend(loc='upper left',bbox_to_anchor=(0.45, 0.92),ncol=3,fontsize=15,frameon=True)

#legend.get_title().set_fontsize(16)
#for t, l in zip(ridge_plot._legend.texts, new_labels):
#    t.set_text(l)
sns.set(font_scale = 0.1)

plt.savefig('Fig5.png', bbox_inches="tight")
plt.savefig('Fig5.pdf', bbox_inches="tight")


ridge_plot.savefig("Emissions_LightweightingWithModalShift.png")
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\distributions.py:1647: FutureWarning: The `vertical` parameter is deprecated and will be removed in a future version. Assign the data to the `y` variable instead.
#   warnings.warn(msg, FutureWarning)
# <ipython-input-16-164ece014845>:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[0].set_yticklabels(ridge_plot.fig.axes[1].get_yticks(), size = 15)
# <ipython-input-16-164ece014845>:35: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[0].set_xticklabels(ridge_plot.fig.axes[0].get_xticks(), size = 15,rotation = 30)
# <ipython-input-16-164ece014845>:36: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ridge_plot.fig.axes[1].set_xticklabels(ridge_plot.fig.axes[1].get_xticks(), size = 15,rotation = 30)

# %%
fig, ax = plt.subplots(figsize=(11,8))
mask= ResultsDF['Regulated EV manufacture'] == 0
im=ax.scatter(ResultsDF[mask].Energy/1e12,ResultsDF[mask].Emissions, marker='^', c=ResultsDF[mask]['Scrap Age'],cmap='viridis' ,s=20)
ax.scatter(ResultsDF[~mask].Energy/1e12,ResultsDF[~mask].Emissions, marker='o', c=ResultsDF[mask]['Scrap Age'],cmap='viridis',s=20 )
plt.legend(['No EV Manufacture Regulations','EV Manufacture Regulations','test3'])
fig.colorbar(im, ax=ax,label='Modal Shift Percentage')
plt.savefig('EnergyEmissionsPlot.png')
plt.xlabel('Cumulative Energy to 2050 (EJ)')
plt.ylabel('Cumulative Emissions to 2050 (MtCO2e)')
plt.axhline(y=21.7, ls='--', c='red')
plt.show()
#plt.scatter(ResultsDF.Energy,ResultsDF.Emissions,c=ResultsDF['Modal Shift'],s=2)

# %%
fig, ax = plt.subplots(figsize=(11,8))
mask= ResultsDF['Regulated EV manufacture'] == 0
im=ax.scatter(ResultsDF[mask]['Modal Shift'],ResultsDF[mask].Emissions, marker='^', c=ResultsDF[mask]['Modal Shift'],cmap='viridis' ,s=20)
ax.scatter(ResultsDF[~mask]['Modal Shift'],ResultsDF[~mask].Emissions, marker='o', c=ResultsDF[mask]['Modal Shift'],cmap='viridis',s=20 )
plt.legend(['No EV Manufacture Regulations','EV Manufacture Regulations','test3'])
fig.colorbar(im, ax=ax,label='Modal Shift Percentage')
plt.savefig('EnergyEmissionsPlot.png')
plt.xlabel('Cumulative Energy to 2050 (TJ)')
plt.ylabel('Cumulative Emissions to 2050 (MtCO2e)')
plt.axhline(y=21.7, ls='--', c='red')
plt.show()
#plt.scatter(ResultsDF.Energy,ResultsDF.Emissions,c=ResultsDF['Modal Shift'],s=2)

# %%
ResultsDF.columns
# Out:
# Index(['Phase-Out', 'Net-Zero', 'Retrofitting', 'Lightweighting',
#        'Modal Shift', 'Scrap Age', 'Regulated EV manufacture', 'Emissions',
#        'Energy'],
#       dtype='object')
